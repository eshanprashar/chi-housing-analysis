# %%
# %load_ext autoreload
# %autoreload 2
import pandas as pd
from chicago_housing.data.load import load_training_data
from chicago_housing.data import clean, distributions
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
#df = load_training_data()   # read
df = load_training_data(property_type="condo")   # read
CITY_COL = "loc_property_city"
MODELING_GROUP_COL = "meta_modeling_group"
SALE_YEAR = "meta_year"
YEARS = ["2022","2023","2024","2025"]
df = df[df[CITY_COL].astype("string").str.upper() == "CHICAGO"]
df = df[df[SALE_YEAR].astype("string").isin(YEARS)]
print(df.shape)
print(df['meta_modeling_group'].value_counts())
# Out:
# (53617, 191)
# meta_modeling_group
# CONDO         52103
# NONLIVABLE     1514
# Name: count, dtype: int64
