# %% [markdown]
# # 02 — The Chicago Hedonic (Post 1.1)
#
# **Guiding question:** what are you paying for — the house, or where it sits?
#
# Steps 1–5 live here as one narrative. `src/` holds the reusable machinery;
# this notebook is the story.
#
# ## Step 1 — One feature first
# Regress `log(sale price)` on a single predictor (building size) and read *every*
# number in the output by hand, before piling on predictors. Goal: fluency, not findings.

# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from chicago_housing import constants as K
from chicago_housing.data.load import load_training_data
from chicago_housing.data import wrangling
from chicago_housing.models import inference, diagnostics

# raw -> model-ready in ONE call (scope + recode + drop non-market + features + logs)
df       = load_training_data(property_type='sf', columns=wrangling.analysis_columns())
model_df = wrangling.build_analytic_sample(df)
model_df.shape
# Out:
# scope_filter [sf]:  405,195 ->   44,015 rows
# recode_categoricals: 10 col(s) -> labels: ['char_air', 'char_attic_fnsh', 'char_attic_type', 'char_bsmt', 'char_bsmt_fin', 'char_gar1_att', 'char_gar1_size', 'char_heat', 'char_porch', 'char_roof_cnst']
# apply_drop_policy: 44,015 -> 40,633
#   statutory (PTAX/family): 2,392
#   below $10,000 floor:    0
#   entity + price-corrob.:  1,362
# analytic sample:                40,633 rows
# (40633, 53)

# %%
# Run the OLS with a single predictor: square footage
res1 = inference.fit_ols(model_df, K.TARGET, ["char_bldg_sf"])
print(res1.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:         log_sale_price   R-squared:                       0.417
# Model:                            OLS   Adj. R-squared:                  0.417
# Method:                 Least Squares   F-statistic:                 2.904e+04
# Date:                Wed, 19 Aug 2026   Prob (F-statistic):               0.00
# Time:                        04:19:31   Log-Likelihood:                -38751.
# No. Observations:               40630   AIC:                         7.751e+04
# Df Residuals:                   40628   BIC:                         7.752e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const           11.5150      0.007   1550.177      0.000      11.500      11.530
# ...

# %% [markdown]
# ### Reading the summary, field by field
#
# Fill these in from the output above — the point is to map each ISL quantity to a real number:
#
# - **coef (`char_bldg_sf`)** — β̂₁: change in *log* price per +1 sqft. Small by construction (1 sqft is tiny). Interpret per 100 sqft in the next cell. Change in 100 sq.ft changes the log price by 0.08 units
# - **coef (`const`)** — β̂₀: fitted log-price at 0 sqft. Not meaningful on its own (extrapolation), just anchors the line. At zero square feet, log price is 11.5 - this doesn't mean much, which is why typically distributions are centered around the mean.
# - **std err** — SE(β̂₁): the slope's uncertainty. This indicates the variation in residuals
# - **t** — β̂₁ / SE. How many SEs the slope sits from zero.
# - **P>|t|** — p-value for H₀: β₁ = 0.
# - **[0.025 0.975]** — 95% CI ≈ β̂₁ ± ~2·SE: slopes compatible with the data.
# - **R-squared** — share of log-price variance explained by size alone.
# - **F-statistic** — joint significance (here, one predictor, so F = t² — verified below).
# - **No. Observations** — N.
#
# > **The big-N caveat (write this into the post):** with ~30k rows the SE is minuscule, t is enormous, p ≈ 0. "Statistically significant" is therefore trivially true and says nothing interesting. The real story is the **effect size** and **R²** — how much size actually moves price, and how much it leaves unexplained.

# %%
tidy  = inference.tidy_coefficients(res1)
stats = inference.fit_summary_stats(res1)
display(tidy)
display(stats.to_frame("value"))
# Out:
#            term       coef   std_err            t  p_value     ci_low  \
# 0         const  11.512526  0.007643  1506.186409      0.0  11.497544
# 1  char_bldg_sf   0.000784  0.000005   165.313221      0.0   0.000775
#
#      ci_high
# 0  11.527507
# 1   0.000793
#                       value
# n_obs          38604.000000
# r_squared          0.414504
# adj_r_squared      0.414489
# rse                0.628874
# f_stat         27328.460992
# f_pvalue           0.000000

# %%
beta = res1.params["char_bldg_sf"]

# Y is log(price), so +100 sqft multiplies price by exp(100*beta)
pct_per_100sqft = (np.exp(100 * beta) - 1) * 100
print(f"+100 sqft  ->  {pct_per_100sqft:.2f}% price change")

# satisfying identity: in simple regression, F == t^2
t = res1.tvalues["char_bldg_sf"]
print(f"F = {res1.fvalue:.2f} ;  t^2 = {t**2:.2f} ;  equal? {np.isclose(res1.fvalue, t**2)}")

# RSE is in log units -> roughly a % spread of the typical residual
print(f"RSE (log units) ≈ {np.sqrt(res1.scale):.3f}  (~{np.sqrt(res1.scale)*100:.0f}% typical miss)")
# Out:
# +100 sqft  ->  8.16% price change
# F = 27328.46 ;  t^2 = 27328.46 ;  equal? True
# RSE (log units) ≈ 0.629  (~63% typical miss)

# %%
s = model_df.sample(min(4000, len(model_df)), random_state=0)  # readable scatter
plt.figure(figsize=(7, 5))
plt.scatter(s["char_bldg_sf"], s[K.TARGET], s=6, alpha=0.25)
xs = np.linspace(s["char_bldg_sf"].quantile(.01), s["char_bldg_sf"].quantile(.99), 100)
plt.plot(xs, res1.params["const"] + beta * xs, color="crimson", lw=2)
plt.xlabel("building sqft"); plt.ylabel("log(sale price)")
plt.title("Step 1: log price vs size, with fitted line")
plt.show()

# %% [markdown]
# ### What to notice (and park for later)
#
# - The line fits, but the cloud **fans out** — residual spread grows with size. That's heteroskedasticity; we don't touch it yet (Step 5 formalizes it), but note it.
# - A straight line on raw sqft imposes "each sqft adds a constant *percent*." Plausible? The curvature you may see here motivates **Step 4**, where we swap to `log(sqft)` and the slope becomes an **elasticity** (% price per % size) — the canonical hedonic form. That before/after is Substack material.
#
# **Next — Step 2:** all of Block A together (multiple regression), the overall F-test, and how much of price the house alone explains.

# %% [markdown]
# ## Step 2 — Block A: the house as a bundle
#
# Now *all* the structural features together. Two questions:
# 1. Does the house, as a bundle, explain price? (**overall F-test**)
# 2. How much does structure alone explain? (**R²** — the "house-only" number for the headline decomposition)
#
# Categoricals (`char_gar1_size`, `char_air`, `char_porch`, `char_bsmt`) are numeric
# *codes*, so they're dummy-encoded via `C()`. Each dummy coefficient reads as
# "% vs the reference level," not "% per unit."

# %%
# Build the regression formula
formula_A = inference.build_formula(K.TARGET, K.BLOCK_A_STRUCTURE, K.CATEGORICAL)
print(formula_A, "\n")

# %%
# Run OLS with Block A parameters as predictors
resA = inference.fit_formula(model_df, formula_A)
print(resA.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:         log_sale_price   R-squared:                       0.485
# Model:                            OLS   Adj. R-squared:                  0.485
# Method:                 Least Squares   F-statistic:                     2012.
# Date:                Sat, 01 Aug 2026   Prob (F-statistic):               0.00
# Time:                        18:03:53   Log-Likelihood:                -34232.
# No. Observations:               38490   AIC:                         6.850e+04
# Df Residuals:                   38471   BIC:                         6.867e+04
# Df Model:                          18
# Covariance Type:            nonrobust
# ...
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept                  9.0033      0.209     43.072      0.000       8.594       9.413
# ...

# %%
statsA = inference.fit_summary_stats(resA)
print("Block A (all structure):")
print(f"  N            : {int(statsA['n_obs']):,}")
print(f"  R²           : {statsA['r_squared']:.3f}   <- the 'house-only' number")
print(f"  Adj R²       : {statsA['adj_r_squared']:.3f}")
print(f"  RSE (log)    : {statsA['rse']:.3f}")
print(f"  F-stat       : {statsA['f_stat']:,.0f}  (p={statsA['f_pvalue']:.1e})")

# how much did the rest of structure add beyond size alone?
r2_size_only = res1.rsquared
print(f"\nR² size-only (Step 1) : {r2_size_only:.3f}")
print(f"R² all structure      : {statsA['r_squared']:.3f}")
print(f"gain from Block A     : +{statsA['r_squared'] - r2_size_only:.3f}")
# Out:
# Block A (all structure):
#   N            : 38,490
#   R²           : 0.485   <- the 'house-only' number
#   Adj R²       : 0.485
#   RSE (log)    : 0.589
#   F-stat       : 2,012  (p=0.0e+00)
#
# R² size-only (Step 1) : 0.415
# R² all structure      : 0.485
# gain from Block A     : +0.070

# %%
tidyA = inference.tidy_coefficients(resA)

# continuous effects in human units (log coef -> %)
def pct(logcoef, mult=1):
    return (np.exp(logcoef * mult) - 1) * 100

cont = tidyA[tidyA["term"].isin(K.BLOCK_A_STRUCTURE)].copy()
cont["interpretation"] = [
    f"+100 sqft -> {pct(b,100):+.1f}%" if t=="char_bldg_sf" else
    f"+1000 sqft lot -> {pct(b,1000):+.1f}%" if t=="char_land_sf" else
    f"+1 year newer -> {pct(b):+.2f}%" if t=="char_yrblt" else
    f"+1 unit -> {pct(b):+.1f}%"
    for t, b in zip(cont["term"], cont["coef"])
]
display(cont[["term","coef","p_value","interpretation"]])

# categorical dummies read as % vs the (dropped) reference level
cat = tidyA[tidyA["term"].str.startswith("C(")].copy()
cat["pct_vs_ref"] = pct(cat["coef"])
display(cat[["term","coef","pct_vs_ref","p_value"]])

# %% [markdown]
# ### What to notice
#
# - **Overall F is astronomically significant** — but with ~30k rows that's trivially true (the big-N caveat again). The real content is **R²**.
# - **R² ≈ [your number]** is the *house-only* baseline. Structure alone explains this much of price; whatever's left is the room for **location** to fill.
# - **Watch `char_bldg_sf` vs Step 1.** Its coefficient shifts once the other structural features are controlled — the first small taste of the confounding-correction we documented (size was partly proxying beds/baths/lot). The *big* correction comes in Step 3 when location enters.
# - **Degenerate categoricals** (`char_porch` ~79% one value, `char_bsmt` ~74%) will have wide, unstable dummy SEs — expected; low variance = little to estimate from.
#
# **Next — Step 3:** add Block B (location). The R² lift from here to there *is the headline*: "structure explains X%, location pushes it to Y%."

# %%
for col in ["char_air", "char_bsmt", "char_porch", "char_gar1_size"]:
    print(model_df[col].value_counts())
# Out:
# char_air
# 2    23664
# 1    14938
# Name: count, dtype: int64
# char_bsmt
# 1    28409
# 2     6261
# 3     3296
# 4      636
# Name: count, dtype: int64
# char_porch
# 0    30440
# 1     7622
# 2      448
# Name: count, dtype: int64
# char_gar1_size
# 3    20538
# 7     7699
# 1     6459
# 2     2419
# 4     1051
# 5      376
# 8       35
# 6       15
# Name: count, dtype: int64

# %%
for c in ["char_air", "char_bsmt", "char_porch", "char_gar1_size"]:
    print(c, "|", model_df[c].dtype, "|", sorted(model_df[c].dropna().unique().tolist()))
# Out:
# char_air | category | ['1', '2']
# char_bsmt | category | ['1', '2', '3', '4']
# char_porch | category | ['0', '1', '2']
# char_gar1_size | category | ['1', '2', '3', '4', '5', '6', '7', '8']

# %% [markdown]
# ## Step 3 — Add Block B (location): the money question
#
# Does *where* a house sits explain price **beyond the house itself**? We build up
# three nested models and test each addition as a group:
#
# - **A** = structure (house only) — R² already ≈ 0.482
# - **A + B** = + location/access
# - **A + B + D** = + demographics (who lives there)
#
# "Where it sits" = B + D together. Three things to watch:
# 1. **Partial-F** — does each block add explanatory power as a *group*?
# 2. **R² jump** — the headline decomposition ("structure X%, location lifts to Y%").
# 3. **Coefficient shifts** — do the structural coefficients move as location enters? (confounding-correction at full scale)

# %%
from statsmodels.stats.anova import anova_lm

# nested F-tests REQUIRE identical rows -> one complete-case frame across all predictors
all_preds = K.BLOCK_A_STRUCTURE + K.BLOCK_B_LOCATION + K.DEMOGRAPHICS
fit_df = model_df.dropna(subset=all_preds).copy()
print(f"complete-case frame: {len(fit_df):,} rows (was {len(model_df):,})\n")

fA   = inference.build_formula(K.TARGET, K.BLOCK_A_STRUCTURE, K.CATEGORICAL)
fAB  = inference.build_formula(K.TARGET, K.BLOCK_A_STRUCTURE + K.BLOCK_B_LOCATION, K.CATEGORICAL)
fABD = inference.build_formula(K.TARGET, K.BLOCK_A_STRUCTURE + K.BLOCK_B_LOCATION + K.DEMOGRAPHICS, K.CATEGORICAL)

mA   = inference.fit_formula(fit_df, fA)
mAB  = inference.fit_formula(fit_df, fAB)
mABD = inference.fit_formula(fit_df, fABD)

# %%
print("R² progression (all on the same rows):")
for name, m in [("A   structure only", mA), ("A+B  +location", mAB), ("A+B+D +demographics", mABD)]:
    print(f"  {name:22s} R²={m.rsquared:.3f}   adjR²={m.rsquared_adj:.3f}")

lift_loc = mAB.rsquared - mA.rsquared
lift_dem = mABD.rsquared - mAB.rsquared
print(f"\nstructure alone      : {mA.rsquared:.1%}")
print(f"+ location adds      : +{lift_loc:.1%}")
print(f"+ demographics adds  : +{lift_dem:.1%}")
print(f"'where it sits' total: +{mABD.rsquared - mA.rsquared:.1%}  ->  full model {mABD.rsquared:.1%}")
# Out:
# R² progression (all on the same rows):
#   A   structure only     R²=0.485   adjR²=0.485
#   A+B  +location         R²=0.687   adjR²=0.687
#   A+B+D +demographics    R²=0.727   adjR²=0.727
#
# structure alone      : 48.5%
# + location adds      : +20.2%
# + demographics adds  : +4.0%
# 'where it sits' total: +24.2%  ->  full model 72.7%

# %%
# nested comparison: A -> A+B -> A+B+D
print(anova_lm(mA, mAB, mABD).round(3))
# Out:
#    df_resid        ssr  df_diff   ss_diff         F  Pr(>F)
# 0   38165.0  13233.516      0.0       NaN       NaN     NaN
# 1   38155.0   8042.382     10.0  5191.134  2827.633     0.0
# 2   38152.0   7004.167      3.0  1038.215  1885.067     0.0

# %%
watch = ["char_bldg_sf", "char_beds", "char_fbath", "char_yrblt", "char_land_sf"]
shift = pd.DataFrame({
    "A":     mA.params.reindex(watch),
    "A+B":   mAB.params.reindex(watch),
    "A+B+D": mABD.params.reindex(watch),
})
shift["% change A→full"] = (shift["A+B+D"] / shift["A"] - 1) * 100
display(shift.round(6))
print("Watch char_bldg_sf: does the size premium shrink once we control for WHERE the big houses are?")
# Out:
#                      A       A+B     A+B+D  % change A→full
# char_bldg_sf  0.000565  0.000367  0.000288       -49.041109
# char_beds    -0.034502  0.002211  0.021128      -161.236976
# char_fbath    0.150846  0.086225  0.068225       -54.771421
# char_yrblt    0.001517  0.002191  0.001675        10.404006
# char_land_sf -0.000017  0.000047  0.000044      -361.888989
# Watch char_bldg_sf: does the size premium shrink once we control for WHERE the big houses are?

# %%
# VIF on the continuous predictors (categoricals excluded); demographics is where it fires
numeric_preds = [
    "char_bldg_sf", "char_land_sf", "char_yrblt", "char_beds", "char_fbath",
    "dist_to_loop_ft", "prox_lake_michigan_dist_ft", "prox_nearest_cta_stop_dist_ft",
    "prox_nearest_park_dist_ft", "prox_nearest_grocery_store_dist_ft",
    "prox_avg_school_rating_in_half_mile", "loc_access_cmap_walk_total_score",
    "prox_nearest_major_road_dist_ft", "prox_num_foreclosure_per_1000_pin_past_5_years",
    "acs5_median_income_household_past_year", "acs5_percent_education_bachelor",
    "acs5_percent_household_owner_occupied",
]
display(diagnostics.vif_table(fit_df, numeric_preds))
print("\nIncome & education should show the highest VIF — they're near-proxies (the deliberate demo).")
# Out:
#                                            feature       vif
# 0           acs5_median_income_household_past_year  4.259338
# 1                                  dist_to_loop_ft  4.046441
# 2                  acs5_percent_education_bachelor  3.933418
# 3                                     char_bldg_sf  3.421066
# 4            acs5_percent_household_owner_occupied  2.742508
# 5                                       char_fbath  2.741494
# 6                 loc_access_cmap_walk_total_score  2.700111
# 7                    prox_nearest_cta_stop_dist_ft  2.417955
# 8                       prox_lake_michigan_dist_ft  2.199861
# 9                                        char_beds  2.024395
# 10  prox_num_foreclosure_per_1000_pin_past_5_years  1.952911
# 11                                    char_land_sf  1.543195
# 12             prox_avg_school_rating_in_half_mile  1.445863
# 13                                      char_yrblt  1.332186
# ...

# %% [markdown]
# ### What to notice
#
# - **R² jump is the headline.** Structure ≈ 48%; location + demographics push it toward ~65–75%. "Well over half of what's left after the house is about *where*."
# - **Partial-F: both blocks are jointly significant** — but (big-N caveat) that's expected; the *effect size* is the R² lift, not the F.
# - **Structural coefficients shifted.** `char_bldg_sf` almost certainly *dropped* when location entered — part of what looked like "size premium" was really "big houses sit in nicer areas." That shift *is* omitted-variable-bias correction, quantified.
# - **VIF fires on income & education** (expect >5, maybe >10). This is the multicollinearity demo: two near-proxies fighting over shared variance → unstable individual coefficients. Fix options (drop one / PCA) are a Step-4 refinement.
# - **Assumption map, live:** we've now attacked Tier 3 exogeneity (added observed confounders). Tier 1 (heteroskedasticity/spatial SE) is Step 5; the unobserved confounder (condition) stays uncorrectable.
#
# **Next — Step 5** (detection): residual diagnostics + Moran's I → *the errors cluster in space*, the 1.1 cliffhanger. (Step 4's log-log/interactions can slot in before or after.)

# %%
# model_df already carries log_* features from build_analytic_sample (§ setup)
LOG_A = ["log_char_bldg_sf", "log_char_land_sf", "char_yrblt", "char_beds", "char_fbath",
         "char_gar1_size", "char_air", "char_porch", "char_bsmt"]

LOG_B = ["dist_to_loop_ft", "prox_lake_michigan_dist_ft", "prox_nearest_cta_stop_dist_ft",
         "prox_nearest_park_dist_ft", "prox_nearest_grocery_store_dist_ft",
         "prox_avg_school_rating_in_half_mile", "no_rated_school_nearby",
         "loc_access_cmap_walk_total_score", "prox_nearest_major_road_dist_ft",
         "prox_num_foreclosure_per_1000_pin_past_5_years"]

LOG_D = ["log_acs5_median_income_household_past_year",
         "acs5_percent_education_bachelor", "acs5_percent_household_owner_occupied"]

fit_log = model_df.dropna(subset=LOG_A + LOG_B + LOG_D).copy()
f_log = inference.build_formula(K.TARGET, LOG_A + LOG_B + LOG_D, K.CATEGORICAL)
mLOG = inference.fit_formula(fit_log, f_log)

print(f"linear full R² : {mABD.rsquared:.3f}")
print(f"log-log  R²    : {mLOG.rsquared:.3f}")
print(f"\nsize elasticity: {mLOG.params['log_char_bldg_sf']:.3f}")
print("  -> a 1% larger house sells for ~{:.2f}% more".format(mLOG.params['log_char_bldg_sf']))

# %%
# DID IT WORK? the two tests that matter
print("max predicted price:")
print(f"  linear : ${np.exp(mABD.fittedvalues.max()):,.0f}   <- the absurdity")
print(f"  log-log: ${np.exp(mLOG.fittedvalues.max()):,.0f}")

# did the U-shaped variance flatten?
dl = pd.DataFrame({"sqft": fit_log["char_bldg_sf"], "resid": mLOG.resid})
dl["dec"] = pd.qcut(dl["sqft"], 10, labels=False)
print("\nresidual SD by sqft decile (was 0.695 -> 0.555 -> 0.676):")
print(dl.groupby("dec")["resid"].std().round(3).to_string())
# Out:
# max predicted price:
#   linear : $24,976,209   <- the absurdity
#   log-log: $6,168,482
#
# residual SD by sqft decile (was 0.695 -> 0.555 -> 0.676):
# dec
# 0    0.514
# 1    0.472
# 2    0.445
# 3    0.398
# 4    0.415
# 5    0.414
# 6    0.393
# 7    0.396
# 8    0.362
# 9    0.372
