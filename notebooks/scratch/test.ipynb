# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from chicago_housing import config as C
from chicago_housing import constants as K
from chicago_housing.data.load import load_training_data
from chicago_housing.data import wrangling, distributions
from chicago_housing.features import derive
from chicago_housing.analysis import sales_descriptives as sd
from chicago_housing.viz import charts, maps

pd.set_option('display.max_rows', 120)
pd.set_option('display.float_format', lambda v: f'{v:,.3f}')

# %%
# Load raw SF parquet + carve the Chicago / SF / 2022-2025 scope
df = load_training_data(property_type='sf')
outliers = df.loc[df['sv_is_outlier']]
reasons = outliers[['meta_sale_buyer_name','meta_sale_seller_name','sv_outlier_reason','sv_outlier_reason2','sv_outlier_reason3']]
reasons['sv_outlier_reason'].value_counts()
# Out:
# sv_outlier_reason
# Algorithm: Outlier Sale, Low price, Low price per square foot, Non-person sale                       3938
# Algorithm: Outlier Sale, Low price, Low price per square foot, PTAX-203 Exclusion                    3448
# Algorithm: Outlier Sale, Low price per square foot, Non-person sale                                  1315
# Algorithm: Outlier Sale, Low price, Non-person sale                                                  1211
# Algorithm: Outlier Sale, Low price, Low price per square foot                                        1210
# Algorithm: Outlier Sale, Low price per square foot, PTAX-203 Exclusion, Non-person sale              1045
# Algorithm: Outlier Sale, High price, High price per square foot, Non-person sale                      975
# Algorithm: Outlier Sale, Low price, PTAX-203 Exclusion, Non-person sale                               945
# Algorithm: Outlier Sale, High price                                                                   899
# Algorithm: Outlier Sale, High price, Non-person sale                                                  760
# Review: Major Characteristic Change                                                                   743
# Algorithm: Outlier Sale, High price per square foot                                                   691
# Algorithm: Outlier Sale, Low price per square foot                                                    670
# Algorithm: Outlier Sale, Low price                                                                    625
# Algorithm: Outlier Sale, High price per square foot, Statistical Anomaly                              539
# Algorithm: Outlier Sale, High price, Non-person sale, Statistical Anomaly                             489
# Algorithm: Outlier Sale, High price, High price per square foot                                       485
# Algorithm: Outlier Sale, High price, Statistical Anomaly                                              478
# Algorithm: Outlier Sale, High price, High price per square foot, Statistical Anomaly                  454
# Algorithm: Outlier Sale, High price per square foot, Non-person sale                                  434
# Review: Non-Arms-Length, Algorithm: Low price                                                         413
# Algorithm: Outlier Sale, High price per square foot, Non-person sale, Statistical Anomaly             269
# Algorithm: Outlier Sale, High price, High price per square foot, Short-term owner                     248
# Algorithm: Outlier Sale, Low price, Low price per square foot, Short-term owner                       237
# Algorithm: Outlier Sale, Low price, Low price per square foot, Statistical Anomaly                    234
# Algorithm: Outlier Sale, High price per square foot, Short-term owner, Non-person sale                195
# Algorithm: Outlier Sale, Low price per square foot, Non-person sale, Statistical Anomaly              180
# Algorithm: Outlier Sale, Low price, Low price per square foot, Family Sale                            152
# Algorithm: Outlier Sale, Low price, Non-person sale, Statistical Anomaly                              139
# Algorithm: Outlier Sale, Low price per square foot, Short-term owner, Non-person sale                 139
# Algorithm: Outlier Sale, Low price per square foot, Statistical Anomaly                               138
# Algorithm: Outlier Sale, Low price, Statistical Anomaly                                               110
# Algorithm: Outlier Sale, High price, Short-term owner, Non-person sale                                106
# Algorithm: Outlier Sale, Low price per square foot, PTAX-203 Exclusion                                102
# Algorithm: Outlier Sale, Low price, Short-term owner, Non-person sale                                 101
# Review: Non-Arms-Length, Algorithm: Low price per square foot                                          87
# Algorithm: Outlier Sale, Low price, PTAX-203 Exclusion                                                 70
# Algorithm: Outlier Sale, High price, PTAX-203 Exclusion, Non-person sale                               47
# Algorithm: Outlier Sale, High price per square foot, Short-term owner                                  47
# Review: Flip, Algorithm: Low price                                                                     42
# Algorithm: Outlier Sale, High price, High price per square foot, PTAX-203 Exclusion                    41
# Algorithm: Outlier Sale, Low price per square foot, Family Sale                                        41
# Algorithm: Outlier Sale, High price, Short-term owner                                                  37
# Algorithm: Outlier Sale, Low price, Family Sale                                                        30
# Algorithm: Outlier Sale, High price per square foot, PTAX-203 Exclusion, Non-person sale               26
# Algorithm: Outlier Sale, High price, PTAX-203 Exclusion                                                23
# Algorithm: Outlier Sale, High price per square foot, PTAX-203 Exclusion                                20
# Algorithm: Outlier Sale, High price per square foot, Short-term owner, Statistical Anomaly             18
# Algorithm: Outlier Sale, Low price per square foot, PTAX-203 Exclusion, Family Sale                    17
# Algorithm: Outlier Sale, Low price, PTAX-203 Exclusion, Family Sale                                    16
# Algorithm: Outlier Sale, Low price per square foot, PTAX-203 Exclusion, Short-term owner               14
# Algorithm: Outlier Sale, Low price per square foot, PTAX-203 Exclusion, Statistical Anomaly            11
# Algorithm: Outlier Sale, Low price, Family Sale, Statistical Anomaly                                   11
# Algorithm: Outlier Sale, Low price per square foot, Short-term owner                                   11
# Algorithm: Outlier Sale, High price per square foot, Non-person sale, Price swing / Home flip          10
# Algorithm: Outlier Sale, High price per square foot, Statistical Anomaly, Price swing / Home flip      10
# Algorithm: Outlier Sale, High price per square foot, Short-term owner, Price swing / Home flip         10
# Algorithm: Outlier Sale, Low price, Short-term owner                                                   10
# Review: Flip, Algorithm: Low price per square foot                                                      9
# Algorithm: Outlier Sale, High price, PTAX-203 Exclusion, Statistical Anomaly                            8
# Algorithm: Outlier Sale, High price per square foot, Family Sale                                        8
# Algorithm: Outlier Sale, High price, Short-term owner, Price swing / Home flip                          7
# Review: Non-Arms-Length, Algorithm: High price                                                          7
# Algorithm: Outlier Sale, High price per square foot, Price swing / Home flip                            7
# Algorithm: Outlier Sale, Low price, PTAX-203 Exclusion, Short-term owner                                7
# Algorithm: Outlier Sale, High price, Short-term owner, Statistical Anomaly                              7
# Algorithm: Outlier Sale, Low price per square foot, Family Sale, Statistical Anomaly                    6
# Algorithm: Outlier Sale, High price, Non-person sale, Price swing / Home flip                           5
# Algorithm: Outlier Sale, High price per square foot, PTAX-203 Exclusion, Family Sale                    5
# Algorithm: Outlier Sale, High price per square foot, PTAX-203 Exclusion, Short-term owner               5
# Algorithm: Outlier Sale, Low price, PTAX-203 Exclusion, Statistical Anomaly                             4
# Review: Flip, Algorithm: High price                                                                     4
# Review: Flip, Algorithm: High price per square foot                                                     4
# Algorithm: Outlier Sale, High price, PTAX-203 Exclusion, Short-term owner                               4
# Algorithm: Outlier Sale, High price, High price per square foot, Price swing / Home flip                4
# Algorithm: Outlier Sale, High price, Price swing / Home flip                                            3
# Algorithm: Outlier Sale, High price, Family Sale, Statistical Anomaly                                   3
# Algorithm: Outlier Sale, High price, Family Sale                                                        3
# Algorithm: Outlier Sale, High price, High price per square foot, Family Sale                            3
# Algorithm: Outlier Sale, High price per square foot, Family Sale, Statistical Anomaly                   3
# Algorithm: Outlier Sale, High price, High price per square foot, Raw price threshold                    3
# Algorithm: Outlier Sale, High price, Statistical Anomaly, Price swing / Home flip                       3
# Algorithm: Outlier Sale, Low price per square foot, Short-term owner, Price swing / Home flip           2
# Algorithm: Outlier Sale, Low price per square foot, Non-person sale, Price swing / Home flip            2
# Algorithm: Outlier Sale, High price, Low price per square foot, PTAX-203 Exclusion                      2
# Algorithm: Outlier Sale, High price, Raw price threshold, Non-person sale                               1
# Algorithm: Outlier Sale, High price per square foot, PTAX-203 Exclusion, Statistical Anomaly            1
# Algorithm: Outlier Sale, Low price, Short-term owner, Price swing / Home flip                           1
# Algorithm: Outlier Sale, Low price, Short-term owner, Statistical Anomaly                               1
# Algorithm: Outlier Sale, Low price, Statistical Anomaly, Price swing / Home flip                        1
# Review: Non-Arms-Length, Algorithm: High price per square foot                                          1
# Name: count, dtype: int64
